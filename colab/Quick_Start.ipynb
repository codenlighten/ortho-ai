# %% [markdown]
# # OKADFA Quick Start - 10 Minutes
#
# Get started with OKADFA in just 10 minutes!
#
# **What you'll do:**
# 1. ✅ Enable GPU
# 2. 📦 Install OKADFA
# 3. 🧪 Run quick test
# 4. 📊 See results
#
# ---

# %%
# Step 1: Check GPU (should show Tesla T4 or similar)
# Go to: Runtime → Change runtime type → GPU → Save
# !nvidia-smi

# %%
# Step 2: Install OKADFA
# !git clone https://github.com/codenlighten/ortho-ai.git
# %cd ortho-ai
# !pip install -q torch datasets transformers tqdm

# %%
# Step 3: Run quick test (takes ~3 minutes)
# !python scripts/train_wikitext.py \
    --max_steps 100 \
    --device cuda \
    --d_model 256 \
    --num_layers 4 \
    --num_heads 4 \
    --batch_size 8 \
    --eval_interval 25 \
    --log_interval 10

# %% [markdown]
# ## ✅ Success!
#
# If you see:
# - **Val PPL decreasing** (e.g., 49,000 → 30,000)
# - **Learning rate increasing** during warmup (e.g., 6e-06 → 6e-05)
# - **Loss decreasing** (e.g., 10.9 → 10.3)
#
# Then OKADFA is working! 🎉
#
# ## 🚀 Next Steps:
#
# Open the full **OKADFA_Training.ipynb** notebook for:
# - Extended training (1000+ steps)
# - Larger models (GPT-2 Small/Medium)
# - Benchmark comparisons
# - Result visualization
#
# ---
#
# **Quick Stats:**
# - 🚄 16.7x faster on GPU vs CPU
# - 📉 31.8% perplexity improvement demonstrated
# - 🧠 Biologically-inspired learning (DFA)
# - 🎯 Orthogonalized attention kernels
